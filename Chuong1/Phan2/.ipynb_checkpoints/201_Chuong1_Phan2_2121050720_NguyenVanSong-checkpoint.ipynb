# %% [markdown]
# <center>
#     <img src='images/logo.png' width='400px'>
#     <h1>MÔN HỌC: THỊ GIÁC MÁY TÍNH (7080518)</h1>
#     <h2> Chương 1: Tổng quan về thị giác máy tính - Phần 2 </h2>
# </center>
#
#
# ---
# **Thông tin sinh viên**
# 1. Họ và tên: Nguyễn Văn Sông
# 2. Mã Sinh viên: 2121050720
# 3. Lớp: DCCTCT66-07A
# 4. Chuyên ngành: Khoa học máy tính và ứng dụng
# 5. Khoa: Công nghệ thông tin
# 6. Khóa: k66
# 7. Môn học: Thị giác máy tính
# 8. Nhóm học: 201
# 9. Giảng viên giảng dạy: Đoàn Văn Nam
#
# ---
# *Copyright: Nguyễn Văn Sông - 2121050720 - DCCTCT66-07A - Khoa học máy tính ứng dụng*

# %%
#Import các thư viện sử dụng
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## THỰC HÀNH 1.4:
# ---
# Yêu cầu:
# 1. Học viên đọc ảnh images/Thuchanh_1.jpg dạng và hiển thị ảnh
# 2. Cho biết kích thước của ảnh và hiển thị ma trận pixel điểm ảnh
# 3. Tách lấy ảnh đôi mắt của cô gái và ghi ảnh đó vào thư mục images/Saves đặt tên file MSV_eyes.png

# %%
#{SINH VIÊN VIẾT CODE VÀO ĐÂY}
img_girl = cv2.imread('images/Thuchanh1.jpg',0)

#Hiển thị ảnh:
plt.figure(figsize=(8,10))
plt.imshow(img_girl,cmap='gray')
plt.title('Ảnh của một cô gái')
plt.grid(ls='--')
plt.show()

# %%
#b) Cho biết kích thước của ảnh
print('Kích thước của ảnh',img_girl.shape)
print('Số pixel của ảnh thực hành:',img_girl.size)
# Out:
# Kích thước của ảnh (366, 550)
# Số pixel của ảnh thực hành: 201300

# %%
#ma trận dữ liệu điểm ảnh
print(img_girl)
# Out:
# [[ 68  69  70 ... 151 150 147]
#  [ 67  68  69 ... 154 152 149]
#  [ 66  67  68 ... 157 156 153]
#  ...
#  [ 24  23  23 ... 190 190 191]
#  [ 24  22  22 ... 188 189 189]
#  [ 25  24  22 ... 188 188 188]]

# %%
#c) Tách lấy một chú mèo và lưu lại
img_eyes = img_girl[75:125,350:450]

plt.imshow(img_eyes,cmap='gray')

# %%
# Luu ảnh
cv2.imwrite('images/Saves/2121050720_eyes.jpg',img_eyes)
# Out:
# True

# %% [markdown]
# ## THỰC HÀNH 1.5:
# ---
# Yêu cầu:
# 1. Sinh viên đọc ảnh màu images/Thuchanh_5.jpg
# 2. Cho biết chiều cao, chiều rộng và số pixel điểm ảnh.
# 3. Tách thành các kênh màu B-G-R tương ứng và hiển thị như yêu cầu trong slide
# 4. Ghi từng kênh màu thành các ảnh riêng vào thư mục images/Saves đặt tên như sau: MSV_blue.jpg; MSV_green.jpg; MSV_red.jpg

# %%
#{SINH VIÊN VIẾT CODE VÀO ĐÂY}
#Import các thư viện sử dụng
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
#1. Đọc ảnh với chế độ mặc định: 
img_th2 = cv2.imread('images/Thuchanh2.jpg')

# Hiển thị ảnh
plt.figure(figsize=(12,6))
plt.imshow(img_th2)
plt.title('Thực hành 2')
plt.show()

# %%
#2. Hiển thị thông tin ảnh:
print('Số pixel trên ảnh:',img_th2.size)
print('Chiều cao của ảnh:',img_th2.shape[0])
print('Chiều rộng của ảnh:',img_th2.shape[1])
print('Kích thước của ảnh:',img_th2.shape)
# Out:
# Số pixel trên ảnh: 877968
# Chiều cao của ảnh: 402
# Chiều rộng của ảnh: 728
# Kích thước của ảnh: (402, 728, 3)

# %%
#3. Tách các kênh màu B, G, R từ ảnh màu
#Khai báo 2 biến chứa 3 kênh màu G-R-B:
height = img_th2.shape[0]
width = img_th2.shape[1]
print('Chiều cao ảnh:',height)
print('Chiều rộng ảnh:',width)
blue=np.zeros((height,width,3),np.uint8)
green=np.zeros((height,width,3),np.uint8)
red=np.zeros((height,width,3),np.uint8)
#-----------------------------------------
#Lấy màu từng pixel tương ứng với mỗi kênh:
for x in range(height):
    for y in range(width):
        B=img_th2[x,y,0] #Kênh màu Blue: 0
        G=img_th2[x,y,1] #Kênh màu Green: 1
        R=img_th2[x,y,2] #Kênh màu Red: 2
        
        blue[x,y,0]=B
        green[x,y,1]=G
        red[x,y,2]=R
# Out:
# Chiều cao ảnh: 402
# Chiều rộng ảnh: 728

# %%
#Hiển thị ảnh gốc và các kênh màu RGB với Matplotlib
plt.figure(figsize=(15,5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(img_th2, cv2.COLOR_BGR2RGB))
plt.title('Ảnh RGB')

plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(blue, cv2.COLOR_BGR2RGB))
plt.title('Blue Channel')

plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(green, cv2.COLOR_BGR2RGB))
plt.title('Green Channel')

plt.subplot(1, 4, 4)
plt.imshow(cv2.cvtColor(red, cv2.COLOR_BGR2RGB))
plt.title('Red Channel')
plt.show()

# %%
#4.Ghi ảnh các kênh màu


#4.Ghi ảnh các kênh màu
cv2.imwrite('images/Saves/2121050720_blue.jpg',blue)
cv2.imwrite('images/Saves/2121050720_green.jpg', green)
cv2.imwrite('images/Saves/2121050720_red.jpg', red)
# Out:
# True

# %% [markdown]
# # THỰC HÀNH 1.6:
# ---
# Yêu cầu: Sinh viên tìm hiểu một số hệ màu cơ bản khác:
#
# ---
# **1. Hệ màu HSV**
# Không gian màu HSB, còn gọi là không gian màu HSV hay không gian màu HSL, là một không gian màu dựa trên ba số liệu:
#
#    - H: (Hue) Vùng màu
#    - S: (Saturation) Độ bão hòa màu
#    - B: (Brightness), V (Value) hay L (Lightness): Độ sáng
# <img src='images/HLSColorSpace.png'> Hình tròn HSV
# <img src='images/180px-HSV_cone.png'> Hình nón HSV
# <img src='images/180px-HSV_cone.jpg'> Một hình nón HSV khác
# <img src='images/180px-HSV_cylinder.png'>Hình trụ HSV
# <img src='images/HSV-RGB-comparison.svg.png'> So sánh HSV-RGB
#
# ***Hình trụ HSV***
#
# HSV được đặt tên như vậy cho ba giá trị: màu sắc, độ bão hòa và giá trị.
# Không gian màu này mô tả màu sắc (màu sắc hoặc màu) về độ bóng (độ bão hòa hoặc lượng màu xám) và giá trị độ sáng của chúng
# Cách sử dụng Mô hình màu HSV
# Bánh xe màu HSV đôi khi được mô tả dưới dạng hình nón hoặc hình trụ, nhưng luôn có ba thành phần sau:
#
# ***HUE***
#
# Hue là phần màu của mô hình màu và được biểu thị dưới dạng một số từ 0 đến 360 độ
#
#
#  <table border="1">
#             <tr>
#                 <td><h3>Màu</h3></td>
#                 <td><h3>Góc</h3></td>
#             </tr>
#             <tr>
#                 <td>Màu đỏ</td>
#                 <td>0-60</td>
#             </tr>
#             <tr>
#                 <td>Màu vàng</td>
#                 <td>60-120</td>
#             </tr>
#             <tr>
#                 <td>màu xanh lá</td>
#                 <td>120-180</td>
#             </tr>
#             <tr>
#                 <td>Cyan</td>
#                 <td>180-240</td>
#             </tr>
#             <tr>
#                 <td>Màu xanh da trời</td>
#                 <td>240-300</td>
#             </tr>
#             <tr>
#                 <td>Màu đỏ tươi</td>
#                 <td>300-360</td>
#             </tr>
#
#  </table>
#
#  ***Độ bão hòa***
#
# Độ bão hòa là lượng màu xám trong màu, từ 0 đến 100 phần trăm. Một hiệu ứng mờ nhạt có thể có được từ việc giảm độ bão hòa về không để giới thiệu nhiều màu xám hơn.
#
# Tuy nhiên, độ bão hòa đôi khi được xem trên phạm vi từ 0-1, trong đó 0 là màu xám và 1 là màu chính.
#
# Giá trị (hoặc Độ sáng)
#
# Giá trị hoạt động kết hợp với độ bão hòa và mô tả độ sáng hoặc cường độ của màu sắc, từ 0-100 phần trăm, trong đó 0 là hoàn toàn đen và 100 là sáng nhất và cho thấy màu sắc nhất.
#
# HSV được sử dụng như thế nào
# Không gian màu HSV được sử dụng khi chọn màu cho sơn hoặc mực vì HSV thể hiện rõ hơn cách mọi người liên quan đến màu sắc hơn không gian màu RGB.
#
# Bánh xe màu HSV cũng được sử dụng để tạo ra đồ họa chất lượng cao. Mặc dù ít được biết đến hơn so với người anh em họ RGB và CMYK, phương pháp HSV có sẵn trong nhiều chương trình phần mềm chỉnh sửa hình ảnh cao cấp.
#
# Chọn màu HSV bắt đầu bằng cách chọn một trong các màu có sẵn, đó là cách hầu hết mọi người liên quan đến màu sắc, sau đó điều chỉnh giá trị độ sáng và độ bóng.
#
# ----------
# **2. Hệ màu CMYK**
#
# Từ CMYK (hay đôi khi là YMCK) là từ viết tắt trong tiếng Anh để chỉ mô hình màu loại trừ sử dụng trong in ấn màu. Mô hình màu này dựa trên cơ sở trộn các chất màu của các màu sau:
#
# C=Cyan trong tiếng Anh có nghĩa là màu xanh lơ hay cánh chả
# M=Magenta trong tiếng Anh có nghĩa là màu cánh sen hay hồng sẫm
# Y=Yellow trong tiếng Anh có nghĩa là màu vàng
# K=Key (trong tiếng Anh nên hiểu theo nghĩa là cái gì đó then chốt hay chủ yếu để ám chỉ màu đen mặc dù màu này có tên tiếng Anh là black do chữ B đã được sử dụng để chỉ màu xanh lam (blue) trong mô hình màu RGB
# để tạo các màu khác.
#
# Hỗn hợp của các màu CMY lý tưởng là loại trừ (các màu này khi in cùng một chỗ trên nền trắng sẽ tạo ra màu đen). Nguyên lý làm việc của CMYK là trên cơ sở hấp thụ ánh sáng. Màu mà người ta nhìn thấy là từ phần của ánh sáng không bị hấp thụ. Trong CMYK hồng sẫm cộng với vàng sẽ cho màu đỏ, cánh sen cộng với xanh lơ cho màu xanh lam, xanh lơ cộng với vàng sinh ra màu xanh lá cây và tổ hợp của các màu xanh lơ, cánh sen và vàng tạo ra màu đen.
#
# Vì màu 'đen' sinh ra bởi việc trộn các màu gốc loại trừ là không thực sự giống như mực đen thật sự hay màu đen của vật đen tuyệt đối (là vật hấp thụ toàn bộ ánh sáng), việc in ấn trên cơ sở bốn màu (đôi khi gọi là in các màu mặc dù điều này không chính xác) phải sử dụng mực đen để bổ sung thêm vào với các màu gốc loại trừ là các màu vàng, cánh sen và xanh lơ.
#
# Việc sử dụng công nghệ in ấn bốn màu sinh ra kết quả in ấn cuối cùng rất cao cấp với độ tương phản cao hơn. Tuy nhiên màu của vật thể mà người ta nhìn thấy trên màn hình máy tính thông thường có sự sai khác chút ít với màu của nó khi in ra vì các mô hình màu CMYK và RGB (sử dụng trong màn hình máy tính) có các gam màu khác nhau. Mô hình màu RGB là mô hình dựa trên cơ sở phát xạ ánh sáng (màu bổ sung) trong khi mô hình CMYK làm việc theo cơ chế hấp thụ ánh sáng (màu loại trừ).
